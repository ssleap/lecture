# %%
import konlpy

# %%
from konlpy.tag import Hannanum as han

# %%
from konlpy.corpus import kolaw

# %%
kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
corpus = kolaw.open('constitution.txt').read()

# %%
type(corpus)
# Out:
# str

# %%
len(corpus)
# Out:
# 18884

# %%
corpus = corpus.split('\n')

# %%
print(corpus[:3])
# Out:
# ['대한민국헌법', '', '유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제·사회·문화의 모든 영역에 있어서 각인의 기회를 균등히 하고, 능력을 최고도로 발휘하게 하며, 자유와 권리에 따르는 책임과 의무를 완수하게 하여, 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 1948년 7월 12일에 제정되고 8차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다.']

# %%
text = '''김의겸 청와대 대변인은 이날 기자들을 만나 "(기무사 계엄령 문건 사태와) 관련된 문건은 현재 각 예하 부대에서 취합을 진행 중인 것으로 안다"며 "극히 일부는 대통령에게 보고가 됐다"고 말했다.

특히 김 대변인은 '현재 알려진 것 외에도 다른 문건이 있는 것인가'라는 질문에 "여러분이 알고 있는 것 말고도 (다른 문건이) 있다"고 말했다.

이어 '그 다른 문건 중 일부가 대통령에게 보고됐다는 것인가'라는 물음에 "그런 취지"라고 답했다.

김 대변인은 다만, '대통령에게 보고된 문건과 관련해 얘기해달라'라는 질문에는 "지금 공개할 수는 없다"고 했다.

또 '문건들이 기무사로부터 다른 부대에 전파·배포된 것인가', '기무사 말고 다른 부대에서도 문건이 나온 것인가' 등의 질문에도 "그건 모르겠다"고만 말했다.

앞서 문 대통령은 지난 16일 "기무사의 '계엄령 문건'과 관련해 국방부·기무사와 각 부대 사이에 오고 간 모든 문서와 보고를 대통령에게 즉시 제출하라"고 지시했다. 

문 대통령의 지시 사항은 국가안보실을 통해 국방부로 전달됐다.'''

# %%
h = han()

# %%
h.pos(text)
# Out:
# [('김의겸', 'N'),
#  ('청와대', 'N'),
#  ('대변인', 'N'),
#  ('은', 'J'),
#  ('이날', 'N'),
#  ('기자들', 'N'),
#  ('을', 'J'),
#  ('만나', 'P'),
#  ('아', 'E'),
#  ('"(기무사', 'N'),
#  ('계엄령', 'N'),
#  ('문건', 'N'),
#  ('사태', 'N'),
#  ('와', 'J'),
#  (')', 'S'),
#  ('관련', 'N'),
#  ('되', 'X'),
#  ('ㄴ', 'E'),
#  ('문건', 'N'),
#  ('은', 'J'),
#  ('현재', 'M'),
#  ('각', 'M'),
#  ('예하', 'N'),
#  ('부대', 'N'),
#  ('에서', 'J'),
#  ('취합', 'N'),
#  ('을', 'J'),
#  ('진행', 'N'),
#  ('중', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('것', 'N'),
#  ('으로', 'J'),
#  ('안다"며', 'N'),
#  ('"', 'S'),
#  ('극히', 'M'),
#  ('일부', 'N'),
#  ('는', 'J'),
#  ('대통령', 'N'),
#  ('에게', 'J'),
#  ('보', 'P'),
#  ('고', 'E'),
#  ('가', 'P'),
#  ('아', 'E'),
#  ('되', 'P'),
#  ('었다', 'E'),
#  ('"', 'S'),
#  ('고', 'J'),
#  ('말', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('특히', 'M'),
#  ('길', 'P'),
#  ('ㅁ', 'E'),
#  ('대변인', 'N'),
#  ('은', 'J'),
#  ("'", 'S'),
#  ('현재', 'N'),
#  ('알리', 'P'),
#  ('어', 'E'),
#  ('지', 'P'),
#  ('ㄴ', 'E'),
# ...

# %%
h.analyze(text)
# Out:
# [[[('김의겸', 'ncn')], [('김의겸', 'nqq')]],
#  [[('청와대', 'ncn')], [('청와대', 'nqq')]],
#  [[('대변인', 'ncn'), ('은', 'jxc')],
#   [('대변인', 'ncn'), ('은', 'ncn')],
#   [('대변', 'ncn'), ('인', 'ncn'), ('은', 'jxc')],
#   [('대변', 'ncpa'), ('인', 'ncn'), ('은', 'jxc')]],
#  [[('이', 'nnc'), ('날', 'nbu')]],
#  [[('기자', 'ncr'), ('들', 'ncn'), ('을', 'jco')]],
#  [[('만나', 'ncn')],
#   [('만', 'nbs'), ('나', 'jcj')],
#   [('만', 'nbs'), ('나', 'jxc')],
#   [('만', 'ncn'), ('나', 'jcj')],
#   [('만', 'ncn'), ('나', 'jxc')],
#   [('만', 'nnc'), ('나', 'jcj')],
#   [('만', 'nnc'), ('나', 'jxc')],
#   [('만나', 'pvg'), ('아', 'ecs')],
#   [('만나', 'pvg'), ('아', 'ecx')],
#   [('만나', 'pvg'), ('아', 'ef')]],
#  [[('"(기무사', 'ncn')], [('"(기무사', 'nqq')]],
#  [[('계엄령', 'ncn')], [('계엄', 'ncpa'), ('령', 'ncn')]],
#  [[('문건', 'ncn')],
#   [('문', 'nbu'), ('건', 'xsnx')],
#   [('문', 'ncn'), ('건', 'xsnx')]],
#  [[('사태', 'ncn'), ('와', 'jcj'), (')', 'sr')],
#   [('사태', 'ncn'), ('와', 'jct'), (')', 'sr')]],
# ...

# %%
textSplit = text.split()

# %%
candidates = h.analyze(text)

# %%
for (i, t) in enumerate(text):
    print(t)
    for c in candidates[i]:
        print('  ',c)
    print()
# Out:
# 김
#    [('김의겸', 'ncn')]
#    [('김의겸', 'nqq')]
#
# 의
#    [('청와대', 'ncn')]
#    [('청와대', 'nqq')]
#
# 겸
#    [('대변인', 'ncn'), ('은', 'jxc')]
#    [('대변인', 'ncn'), ('은', 'ncn')]
#    [('대변', 'ncn'), ('인', 'ncn'), ('은', 'jxc')]
#    [('대변', 'ncpa'), ('인', 'ncn'), ('은', 'jxc')]
#
#
#    [('이', 'nnc'), ('날', 'nbu')]
#
# 청
#    [('기자', 'ncr'), ('들', 'ncn'), ('을', 'jco')]
#
# 와
#    [('만나', 'ncn')]
#    [('만', 'nbs'), ('나', 'jcj')]
#    [('만', 'nbs'), ('나', 'jxc')]
#    [('만', 'ncn'), ('나', 'jcj')]
#    [('만', 'ncn'), ('나', 'jxc')]
#    [('만', 'nnc'), ('나', 'jcj')]
#    [('만', 'nnc'), ('나', 'jxc')]
#    [('만나', 'pvg'), ('아', 'ecs')]
#    [('만나', 'pvg'), ('아', 'ecx')]
#    [('만나', 'pvg'), ('아', 'ef')]
#
# 대
#    [('"(기무사', 'ncn')]
#    [('"(기무사', 'nqq')]
#
#
#    [('계엄령', 'ncn')]
#    [('계엄', 'ncpa'), ('령', 'ncn')]
#
# 대
#    [('문건', 'ncn')]
#    [('문', 'nbu'), ('건', 'xsnx')]
#    [('문', 'ncn'), ('건', 'xsnx')]
#
# 변
#    [('사태', 'ncn'), ('와', 'jcj'), (')', 'sr')]
# ...

# %%
h.pos(text)
# Out:
# [('김의겸', 'N'),
#  ('청와대', 'N'),
#  ('대변인', 'N'),
#  ('은', 'J'),
#  ('이날', 'N'),
#  ('기자들', 'N'),
#  ('을', 'J'),
#  ('만나', 'P'),
#  ('아', 'E'),
#  ('"(기무사', 'N'),
#  ('계엄령', 'N'),
#  ('문건', 'N'),
#  ('사태', 'N'),
#  ('와', 'J'),
#  (')', 'S'),
#  ('관련', 'N'),
#  ('되', 'X'),
#  ('ㄴ', 'E'),
#  ('문건', 'N'),
#  ('은', 'J'),
#  ('현재', 'M'),
#  ('각', 'M'),
#  ('예하', 'N'),
#  ('부대', 'N'),
#  ('에서', 'J'),
#  ('취합', 'N'),
#  ('을', 'J'),
#  ('진행', 'N'),
#  ('중', 'N'),
#  ('이', 'J'),
#  ('ㄴ', 'E'),
#  ('것', 'N'),
#  ('으로', 'J'),
#  ('안다"며', 'N'),
#  ('"', 'S'),
#  ('극히', 'M'),
#  ('일부', 'N'),
#  ('는', 'J'),
#  ('대통령', 'N'),
#  ('에게', 'J'),
#  ('보', 'P'),
#  ('고', 'E'),
#  ('가', 'P'),
#  ('아', 'E'),
#  ('되', 'P'),
#  ('었다', 'E'),
#  ('"', 'S'),
#  ('고', 'J'),
#  ('말', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('특히', 'M'),
#  ('길', 'P'),
#  ('ㅁ', 'E'),
#  ('대변인', 'N'),
#  ('은', 'J'),
#  ("'", 'S'),
#  ('현재', 'N'),
#  ('알리', 'P'),
#  ('어', 'E'),
#  ('지', 'P'),
#  ('ㄴ', 'E'),
# ...

# %%
h.nouns(text)
# Out:
# ['김의겸',
#  '청와대',
#  '대변인',
#  '이날',
#  '기자들',
#  '"(기무사',
#  '계엄령',
#  '문건',
#  '사태',
#  '관련',
#  '문건',
#  '예하',
#  '부대',
#  '취합',
#  '진행',
#  '중',
#  '것',
#  '안다"며',
#  '일부',
#  '대통령',
#  '말',
#  '대변인',
#  '현재',
#  '것',
#  '외',
#  '문건',
#  '것',
#  '질문',
#  '여러분',
#  '것',
#  '문건',
#  '말',
#  '이',
#  '문건',
#  '중',
#  '일부',
#  '대통령',
#  '것',
#  '취지',
#  '답',
#  '대변인',
#  '대통령',
#  '문건',
#  '관련해',
#  "얘기해달라'라",
#  '질문',
#  '공개',
#  '수',
#  '것',
#  '들',
#  '기무사로부터',
#  '부대',
#  '전파·배포된',
#  '것',
#  "'기무사",
#  '부대',
#  '문건',
#  '것',
#  '등',
#  '질문',
#  '그',
#  '말',
#  '대통령',
#  '16일',
#  '"기무사',
#  '계엄령',
#  '것',
#  '관련해',
#  '국방부·기무사',
#  '부대',
#  '사이',
#  '문서',
#  '보고',
#  '대통령',
#  '출하',
#  '지시',
#  '대통령의',
#  '지시',
#  '사항',
#  '국가안보실',
#  '국방부',
#  '전달']

# %%
from konlpy.tag import Kkma as kk

# %%
k = kk()

# %%
senten = k.sentences(text)

# %%
senten
# Out:
# ['김의 겸 청와대 대변인은 이날 기자들을 만 나 "( 기무사 계엄령 문건 사태와) 관련된 문건은 현재 각 예하 부대에서 취합을 진행 중인 것으로 안다 "며 " 극히 일부는 대통령에게 보고가 됐다" 고 말했다.',
#  '특히 김 대변인은 \' 현재 알려 진 것 외에도 다른 문건이 있는 것인가\' 라는 질문에 " 여러분이 알고 있는 것 말고도 ( 다른 문건이) 있다" 고 말했다.',
#  '이어 \' 그 다른 문건 중 일부가 대통령에게 보고됐다는 것인가\' 라는 물음에 " 그런 취지" 라고 답했다.',
#  '김 대변인은 다만, \' 대통령에게 보고된 문건과 관련해 얘기해 달라\' 라는 질문에는 " 지금 공개할 수는 없다" 고 했다.',
#  '또 \' 문건들이 기무사로부터 다른 부대에 전파· 배포된 것인가\', \' 기무사 말고 다른 부대에서도 문건이 나온 것인가\' 등의 질문에도 " 그건 모르겠다" 고만 말했다.',
#  '앞서 문 대통령은 지난 16일 " 기무사의 \' 계 엄령 문건\' 과 관련해 국방부· 기무사와 각 부대 사이에 오고 간 모든 문서와 보고를 대통령에게 즉시 제출하라" 고 지시했다.',
#  '문 대통령의 지시 사항은 국가 안보실을 통해 국방부로 전달됐다.']

# %%
k.nouns(senten[0])
# Out:
# ['김의',
#  '겸',
#  '청와대',
#  '대변인',
#  '이날',
#  '기자',
#  '나',
#  '기무사',
#  '계엄령',
#  '문건',
#  '사태',
#  '관련',
#  '현재',
#  '예하',
#  '부대',
#  '취합',
#  '진행',
#  '중',
#  '일부',
#  '대통령',
#  '보고',
#  '고']

# %%
k.morphs(senten[0])
# Out:
# ['김의',
#  '겸',
#  '청와대',
#  '대변인',
#  '은',
#  '이날',
#  '기자',
#  '들',
#  '을',
#  '마',
#  'ㄴ',
#  '나',
#  '"',
#  '(',
#  '기무사',
#  '계엄령',
#  '문건',
#  '사태',
#  '와',
#  ')',
#  '관련',
#  '되',
#  'ㄴ',
#  '문건',
#  '은',
#  '현재',
#  '각',
#  '예하',
#  '부대',
#  '에서',
#  '취합',
#  '을',
#  '진행',
#  '중',
#  '이',
#  'ㄴ',
#  '것',
#  '으로',
#  '알',
#  'ㄴ다',
#  '"',
#  '며',
#  '"',
#  '극히',
#  '일부',
#  '는',
#  '대통령',
#  '에게',
#  '보고',
#  '가',
#  '되',
#  '었',
#  '다',
#  '"',
#  '고',
#  '말하',
#  '었',
#  '다',
#  '.']

# %%
k.pos(text)
# Out:
# [('김의', 'NNG'),
#  ('겸', 'NNB'),
#  ('청와대', 'NNG'),
#  ('대변인', 'NNG'),
#  ('은', 'JX'),
#  ('이날', 'NNG'),
#  ('기자', 'NNG'),
#  ('들', 'XSN'),
#  ('을', 'JKO'),
#  ('만', 'JX'),
#  ('나', 'NP'),
#  ('"', 'SS'),
#  ('(', 'SS'),
#  ('기무사', 'NNG'),
#  ('계엄령', 'NNG'),
#  ('문건', 'NNG'),
#  ('사태', 'NNG'),
#  ('와', 'JKM'),
#  (')', 'SS'),
#  ('관련', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('문건', 'NNG'),
#  ('은', 'JX'),
#  ('현재', 'NNG'),
#  ('각', 'MDT'),
#  ('예하', 'NNG'),
#  ('부대', 'NNG'),
#  ('에서', 'JKM'),
#  ('취합', 'NNG'),
#  ('을', 'JKO'),
#  ('진행', 'NNG'),
#  ('중', 'NNB'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETD'),
#  ('것', 'NNB'),
#  ('으로', 'JKM'),
#  ('알', 'VV'),
#  ('ㄴ다', 'ECS'),
#  ('"', 'SS'),
#  ('며', 'JC'),
#  ('"', 'SS'),
#  ('극히', 'MAG'),
#  ('일부', 'NNG'),
#  ('는', 'JX'),
#  ('대통령', 'NNG'),
#  ('에게', 'JKM'),
#  ('보고', 'NNG'),
#  ('가', 'JKC'),
#  ('되', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'ECS'),
#  ('"', 'SS'),
#  ('고', 'NNG'),
#  ('말하', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
# ...

# %%
kk.mro()
# Out:
# [konlpy.tag._kkma.Kkma, object]

# %%
k.tagset
# Out:
# {'EC': '연결 어미',
#  'ECD': '의존적 연결 어미',
#  'ECE': '대등 연결 어미',
#  'ECS': '보조적 연결 어미',
#  'EF': '종결 어미',
#  'EFA': '청유형 종결 어미',
#  'EFI': '감탄형 종결 어미',
#  'EFN': '평서형 종결 어미',
#  'EFO': '명령형 종결 어미',
#  'EFQ': '의문형 종결 어미',
#  'EFR': '존칭형 종결 어미',
#  'EP': '선어말 어미',
#  'EPH': '존칭 선어말 어미',
#  'EPP': '공손 선어말 어미',
#  'EPT': '시제 선어말 어미',
#  'ET': '전성 어미',
#  'ETD': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JK': '조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKI': '호격 조사',
#  'JKM': '부사격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JX': '보조사',
#  'MA': '부사',
#  'MAC': '접속 부사',
#  'MAG': '일반 부사',
#  'MD': '관형사',
#  'MDN': '수 관형사',
#  'MDT': '일반 관형사',
#  'NN': '명사',
#  'NNB': '일반 의존 명사',
#  'NNG': '보통명사',
#  'NNM': '단위 의존 명사',
#  'NNP': '고유명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'OH': '한자',
#  'OL': '외국어',
#  'ON': '숫자',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
# ...

# %%
from konlpy.tag import Twitter as tw

# %%
tt = tw()

# %%
tt.morphs(text)
# Out:
# ['김',
#  '의겸',
#  '청와대',
#  '대변인',
#  '은',
#  '이',
#  '날',
#  '기자',
#  '들',
#  '을',
#  '만나',
#  '"(',
#  '기무사',
#  '계엄령',
#  '문건',
#  '사태',
#  '와',
#  ')',
#  '관련된',
#  '문건',
#  '은',
#  '현재',
#  '각',
#  '예하',
#  '부대',
#  '에서',
#  '취합',
#  '을',
#  '진행',
#  '중인',
#  '것',
#  '으로',
#  '안다',
#  '"',
#  '며',
#  '"',
#  '극히',
#  '일부',
#  '는',
#  '대통령',
#  '에게',
#  '보고',
#  '가',
#  '됐',
#  '다',
#  '"',
#  '고',
#  '말했',
#  '다',
#  '.',
#  '특히',
#  '김',
#  '대변인',
#  '은',
#  "'",
#  '현재',
#  '알려진',
#  '것',
#  '외',
#  '에도',
#  '다른',
#  '문건',
#  '이',
#  '있는',
#  '것',
#  '인가',
#  "'",
#  '라는',
#  '질문',
#  '에',
#  '"',
#  '여러분',
#  '이',
#  '알',
#  '고',
#  '있는',
#  '것',
#  '말고도',
#  '(',
#  '다른',
#  '문건',
#  '이',
#  ')',
#  '있다',
#  '"',
#  '고',
#  '말했',
#  '다',
#  '.',
#  '이어',
#  "'",
#  '그',
#  '다른',
#  '문건',
#  '중',
#  '일부',
#  '가',
#  '대통령',
#  '에게',
#  '보고',
#  '됐',
#  '다는',
#  '것',
#  '인가',
#  "'",
#  '라는',
#  '물음',
#  '에',
#  '"',
#  '그런',
#  '취지',
#  '"',
#  '라고',
#  '답했',
#  '다',
#  '.',
# ...

# %%
tt.nouns(text)
# Out:
# ['김',
#  '의겸',
#  '청와대',
#  '대변인',
#  '날',
#  '기자',
#  '기무사',
#  '계엄령',
#  '문건',
#  '사태',
#  '문건',
#  '현재',
#  '각',
#  '예하',
#  '부대',
#  '진행',
#  '중인',
#  '것',
#  '며',
#  '극히',
#  '일부',
#  '대통령',
#  '보고',
#  '고',
#  '김',
#  '대변인',
#  '현재',
#  '것',
#  '외',
#  '다른',
#  '문건',
#  '것',
#  '질문',
#  '여러분',
#  '알',
#  '것',
#  '다른',
#  '문건',
#  '고',
#  '그',
#  '다른',
#  '문건',
#  '중',
#  '일부',
#  '대통령',
#  '보고',
#  '것',
#  '물음',
#  '취지',
#  '김',
#  '대변인',
#  '다만',
#  '대통령',
#  '보고',
#  '문건',
#  '얘기',
#  '질문',
#  '지금',
#  '공개',
#  '수',
#  '고',
#  '또',
#  '문건',
#  '기무사',
#  '로부터',
#  '다른',
#  '부대',
#  '전파',
#  '배포',
#  '것',
#  '기무사',
#  '다른',
#  '부대',
#  '문건',
#  '것',
#  '등',
#  '질문',
#  '앞서',
#  '문',
#  '대통령',
#  '지난',
#  '일',
#  '기무사',
#  '계엄령',
#  '문건',
#  '과',
#  '국방부',
#  '기무사',
#  '각',
#  '부대',
#  '사이',
#  '간',
#  '모든',
#  '문서',
#  '보고',
#  '대통령',
#  '즉시',
#  '제출',
#  '하라',
#  '고',
#  '문',
#  '대통령',
#  '지시',
#  '사항',
#  '국가안보실',
#  '통해',
#  '국방부',
#  '전달']

# %%
tt.phrases(text)
# Out:
# ['김의겸 청와대 대변인',
#  '청와대 대변인',
#  '이날 기자들',
#  '기무사 계엄령 문건 사태',
#  '계엄령 문건 사태',
#  '문건 사태',
#  '문건',
#  '현재 각 예하 부대',
#  '각 예하 부대',
#  '예하 부대',
#  '진행 중인 것',
#  '중인 것',
#  '극히 일부',
#  '대통령',
#  '보고',
#  '김 대변인',
#  '현재',
#  '현재 알려진 것 외',
#  '다른 문건',
#  '질문',
#  '여러분',
#  '그 다른 문건 중 일부',
#  '다른 문건 중 일부',
#  '문건 중 일부',
#  '중 일부',
#  '보고됐다는 것',
#  '물음',
#  '취지',
#  '다만',
#  '보고된 문건',
#  '얘기',
#  '지금 공개',
#  '지금 공개할 수',
#  '공개할 수',
#  '문건들',
#  '기무사로부터 다른 부대',
#  '다른 부대',
#  '전파',
#  '배포',
#  '배포된 것',
#  '기무사',
#  '등의 질문',
#  '앞서 문 대통령',
#  '문 대통령',
#  '지난 16일',
#  '계엄령 문건',
#  '국방부',
#  '기무사와 각 부대 사이',
#  '각 부대 사이',
#  '부대 사이',
#  '간 모든 문서',
#  '모든 문서',
#  '간 모든 문서와 보고',
#  '모든 문서와 보고',
#  '문서와 보고',
#  '즉시 제출하라',
#  '문 대통령의 지시 사항',
#  '대통령의 지시 사항',
#  '지시 사항',
#  '국가안보실',
#  '통해 국방부',
#  '전달',
#  '의겸',
#  '청와대',
#  '대변인',
#  '이날',
#  '기자들',
#  '계엄령',
#  '사태',
#  '예하',
#  '부대',
#  '진행',
#  '중인',
#  '극히',
#  '일부',
#  '다른',
#  '지금',
#  '공개',
#  '로부터',
#  '앞서',
#  '지난',
#  '16',
#  '사이',
# ...

# %%
from matplotlib import pyplot as plt

# %%
corpus
# Out:
# ['대한민국헌법',
#  '',
#  '유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제·사회·문화의 모든 영역에 있어서 각인의 기회를 균등히 하고, 능력을 최고도로 발휘하게 하며, 자유와 권리에 따르는 책임과 의무를 완수하게 하여, 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 1948년 7월 12일에 제정되고 8차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다.',
#  '',
#  '       제1장 총강',
#  '  제1조 ① 대한민국은 민주공화국이다.',
#  '②대한민국의 주권은 국민에게 있고, 모든 권력은 국민으로부터 나온다.',
#  '  제2조 ① 대한민국의 국민이 되는 요건은 법률로 정한다.',
#  '②국가는 법률이 정하는 바에 의하여 재외국민을 보호할 의무를 진다.',
#  '  제3조 대한민국의 영토는 한반도와 그 부속도서로 한다.',
#  '  제4조 대한민국은 통일을 지향하며, 자유민주적 기본질서에 입각한 평화적 통일 정책을 수립하고 이를 추진한다.',
#  '  제5조 ① 대한민국은 국제평화의 유지에 노력하고 침략적 전쟁을 부인한다.',
#  '②국군은 국가의 안전보장과 국토방위의 신성한 의무를 수행함을 사명으로 하며, 그 정치적 중립성은 준수된다.',
#  '  제6조 ① 헌법에 의하여 체결·공포된 조약과 일반적으로 승인된 국제법규는 국내법과 같은 효력을 가진다.',
#  '②외국인은 국제법과 조약이 정하는 바에 의하여 그 지위가 보장된다.',
# ...

# %%
cor = kolaw.open('constitution.txt').read()

# %%
nounList = tt.nouns(cor)

# %%
global_unique = []

# %%
for row in cor.split('\n') : 
    term = tt.nouns(row)
    unique = set(term)
    print(unique)
    global_unique += list(set(unique))
    unique_count = len(global_unique)
    print(global_unique)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {'법률', '교육', '바', '정치', '및', '대학', '전문성', '자주성', '자율성', '중립성'}
# ...
