# %%
import pandas as pd

# %%
import pandas as pd

data_header = ['id' , 'item_id' , 'rating' , 'timestamp']
data = pd.read_csv("ml-100k/u.data",sep='\t', names=data_header, encoding='utf-8')
data.head()

user_header = ['id' ,'age' , 'gender' , 'occupation' , 'zip code']
user = pd.read_csv("ml-100k/u.user",sep='|',names=user_header, encoding='utf-8')
user.head()


item_header = ["id" , "movie_title" , "release_date" , "video_release_date",
               "IMDb_URL" , 'unknown' , 'Action' , 'Adventure' ,'Animation',
               "Children's" , 'Comedy' , 'Crime' ,'Documentary' , 'Drama' , 'Fantasy',
               'Film-Noir', 'Horror' , 'Musical' , 'Mystery' , 'Romance' , 'Sci-Fi',
               'Thriller' , "War" , "Western" ]

# %%
item = pd.read_csv('ml-100k/u.item',sep='|', usecols=range(5), names=item_header, encoding = 'utf-8')
item.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 3: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-54-d1b6fadb00b2> in <module>()
# ----> 1 item = pd.read_csv('ml-100k/u.item',sep='|', usecols=range(5), names=item_header, encoding = 'utf-8')
#       2 item.head()
#
# ...

# %%
import surprise

# %%
data = surprise.Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] Y
# Trying to download dataset from http://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to C:\Users\user/.surprise_data/ml-100k

# %%
data

# %%
dir(data)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'build_full_trainset',
#  'construct_testset',
#  'construct_trainset',
#  'folds',
#  'has_been_split',
#  'load_builtin',
#  'load_from_df',
#  'load_from_file',
#  'load_from_folds',
#  'ratings_file',
#  'raw_folds',
#  'raw_ratings',
#  'read_ratings',
#  'reader',
#  'split']

# %%
data.raw_ratings
# Out:
# [('196', '242', 3.0, '881250949'),
#  ('186', '302', 3.0, '891717742'),
#  ('22', '377', 1.0, '878887116'),
#  ('244', '51', 2.0, '880606923'),
#  ('166', '346', 1.0, '886397596'),
#  ('298', '474', 4.0, '884182806'),
#  ('115', '265', 2.0, '881171488'),
#  ('253', '465', 5.0, '891628467'),
#  ('305', '451', 3.0, '886324817'),
#  ('6', '86', 3.0, '883603013'),
#  ('62', '257', 2.0, '879372434'),
#  ('286', '1014', 5.0, '879781125'),
#  ('200', '222', 5.0, '876042340'),
#  ('210', '40', 3.0, '891035994'),
#  ('224', '29', 3.0, '888104457'),
#  ('303', '785', 3.0, '879485318'),
#  ('122', '387', 5.0, '879270459'),
#  ('194', '274', 2.0, '879539794'),
#  ('291', '1042', 4.0, '874834944'),
#  ('234', '1184', 2.0, '892079237'),
#  ('119', '392', 4.0, '886176814'),
#  ('167', '486', 4.0, '892738452'),
#  ('299', '144', 4.0, '877881320'),
#  ('291', '118', 2.0, '874833878'),
#  ('308', '1', 4.0, '887736532'),
#  ('95', '546', 2.0, '879196566'),
#  ('38', '95', 5.0, '892430094'),
# ...

# %%
import pandas as pd

# %%
user = pd.read_csv('ml-100k/u.user', sep = '|')

# %%
user
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# 5      7  57  M  administrator  91344
# 6      8  36  M  administrator  05201
# 7      9  29  M        student  01002
# 8     10  53  M         lawyer  90703
# 9     11  39  F          other  30329
# 10    12  28  F          other  06405
# 11    13  47  M       educator  29206
# 12    14  45  M      scientist  55106
# 13    15  49  F       educator  97301
# 14    16  21  M  entertainment  10309
# 15    17  30  M     programmer  06355
# 16    18  35  F          other  37212
# 17    19  40  M      librarian  02138
# 18    20  42  F      homemaker  95660
# 19    21  26  M         writer  30068
# 20    22  25  M         writer  40206
# 21    23  30  F         artist  48197
# 22    24  21  F         artist  94533
# 23    25  39  M       engineer  55107
# ...

# %%
data1 = pd.DataFrame(data.raw_ratings)

# %%
data1 = pd.DataFrame.from_records(data.raw_ratings)

# %%
data1
# Out:
#          0     1    2          3
# 0      196   242  3.0  881250949
# 1      186   302  3.0  891717742
# 2       22   377  1.0  878887116
# 3      244    51  2.0  880606923
# 4      166   346  1.0  886397596
# 5      298   474  4.0  884182806
# 6      115   265  2.0  881171488
# 7      253   465  5.0  891628467
# 8      305   451  3.0  886324817
# 9        6    86  3.0  883603013
# 10      62   257  2.0  879372434
# 11     286  1014  5.0  879781125
# 12     200   222  5.0  876042340
# 13     210    40  3.0  891035994
# 14     224    29  3.0  888104457
# 15     303   785  3.0  879485318
# 16     122   387  5.0  879270459
# 17     194   274  2.0  879539794
# 18     291  1042  4.0  874834944
# 19     234  1184  2.0  892079237
# 20     119   392  4.0  886176814
# 21     167   486  4.0  892738452
# 22     299   144  4.0  877881320
# 23     291   118  2.0  874833878
# 24     308     1  4.0  887736532
# 25      95   546  2.0  879196566
# 26      38    95  5.0  892430094
# ...

# %%
data1 = data1.rename({0 : 'user', 1: 'item', 2 : 'rate', 3:'time'}, axis = 1)

# %%
data1.drop('time', axis = 1, inplace = True)

# %%
from surprise.model_selection import cross_validate

# %%
from surprise import Reader

# %%
reader = Reader()

# %%
surprise_data = surprise.Dataset.load_from_df(data1, reader = reader)

# %%
from surprise import NormalPredictor

# %%
algo = NormalPredictor()

# %%
cross_validate(algo,surprise_data, cv = 2)
# Out:
# {'test_rmse': array([1.51459879, 1.51974229]),
#  'test_mae': array([1.2158867, 1.2214405]),
#  'fit_time': (0.06582260131835938, 0.07779169082641602),
#  'test_time': (0.33510470390319824, 0.3371007442474365)}

# %%
x = data1

# %%
x
# Out:
#       user  item  rate
# 0      196   242   3.0
# 1      186   302   3.0
# 2       22   377   1.0
# 3      244    51   2.0
# 4      166   346   1.0
# 5      298   474   4.0
# 6      115   265   2.0
# 7      253   465   5.0
# 8      305   451   3.0
# 9        6    86   3.0
# 10      62   257   2.0
# 11     286  1014   5.0
# 12     200   222   5.0
# 13     210    40   3.0
# 14     224    29   3.0
# 15     303   785   3.0
# 16     122   387   5.0
# 17     194   274   2.0
# 18     291  1042   4.0
# 19     234  1184   2.0
# 20     119   392   4.0
# 21     167   486   4.0
# 22     299   144   4.0
# 23     291   118   2.0
# 24     308     1   4.0
# 25      95   546   2.0
# 26      38    95   5.0
# 27     102   768   2.0
# 28      63   277   4.0
# 29     160   234   5.0
# ...    ...   ...   ...
# 99970  449   120   1.0
# 99971  661   762   2.0
# 99972  721   874   3.0
# 99973  821   151   4.0
# 99974  764   596   3.0
# 99975  537   443   3.0
# 99976  618   628   2.0
# 99977  487   291   3.0
# ...

# %%
x.pivot('user', 'item', 'rate')
# Out:
# item    1   10  100  1000  1001  1002  1003  1004  1005  1006 ...   990  991  \
# user                                                          ...
# 1     5.0  3.0  5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 10    4.0  NaN  5.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 100   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   3.0  NaN
# 101   3.0  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 102   3.0  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 103   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 104   NaN  2.0  4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 105   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 106   4.0  NaN  3.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# 107   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN ...   NaN  NaN
# ...

# %%
y = x.pivot('user', 'item', 'rate')

# %%
import matplotlib.pyplot as plt

# %%
plt.grid(True)
plt.imshow(x)

# %%
from surprise import BaselineOnly

# %%
train_data = surprise_data.build_full_trainset()

# %%
algo1 = surprise.BaselineOnly()
algo1.fit(train_data)
# Out:
# Estimating biases using als...

# %%
algo1.predict('1','1')
# Out:
# Prediction(uid='1', iid='1', r_ui=None, est=3.892353248894885, details={'was_impossible': False})

# %%
algo = surprise.KNNBasic()

# %%
algo.fit(train_data)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
algo.predict('1','1')
# Out:
# Prediction(uid='1', iid='1', r_ui=None, est=4.1299713089494405, details={'actual_k': 40, 'was_impossible': False})
